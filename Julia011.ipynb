# %%
a = Array{Float64}(undef,2,3)
# Out:
# 2×3 Matrix{Float64}:
#  2.3091e-314  2.3091e-314  2.29883e-314
#  2.3091e-314  2.3091e-314  5.0e-324

# %%
m = Matrix{Int}(undef,2,3)
# Out:
# 2×3 Matrix{Int64}:
#  4817513936  4687497168      0
#  4445859952           0  29667

# %%
# in array we can have n dimensions
a1 = Array{Float64}(undef,2,3,4,5,6)
# Out:
# 2×3×4×5×6 Array{Float64, 5}:
# [:, :, 1, 1, 1] =
#  1.0e-323  NaN    2.25355e-314
#  0.0         0.0  1.0e-323
#
# [:, :, 2, 1, 1] =
#    0.0  0.0           1.0e-323
#  NaN    2.25355e-314  0.0
#
# [:, :, 3, 1, 1] =
#  NaN    2.25355e-314    0.0
#    0.0  1.0e-323      NaN
#
# [:, :, 4, 1, 1] =
#  0.0           6.9301e-310  5.21502e-310
#  2.25355e-314  0.0          6.93014e-310
#
# [:, :, 1, 2, 1] =
#  2.25355e-314    0.0  0.0
#  1.0e-323      NaN    2.25355e-314
#
# [:, :, 2, 2, 1] =
#  1.0e-323  NaN    2.25355e-314
#  0.0         0.0  1.0e-323
#
# [:, :, 3, 2, 1] =
#    0.0  0.0           1.0e-323
#  NaN    2.25355e-314  0.0
#
# [:, :, 4, 2, 1] =
#  NaN    2.25355e-314    0.0
#    0.0  1.0e-323      NaN
#
# [:, :, 1, 3, 1] =
#  0.0           1.0e-323  NaN
#  2.25355e-314  0.0         0.0
#
# [:, :, 2, 3, 1] =
#  2.25355e-314    0.0  0.0
#  1.0e-323      NaN    2.25355e-314
#
# [:, :, 3, 3, 1] =
#  1.0e-323  NaN    2.25355e-314
#  0.0         0.0  1.0e-323
#
# [:, :, 4, 3, 1] =
# ...

# %%
# but in matrix we can have only two that is row and columns
m1 = Matrix{Int}(undef,2,3,4)
# Here, it gives us an error as we put 3 dimensions instead of 2
# Out:
# MethodError: no method matching Matrix{Int64}(::UndefInitializer, ::Int64, ::Int64, ::Int64)
# Closest candidates are:
#   Array{T, N}(::UndefInitializer, ::Int64...) where {T, N} at boot.jl:454
#   Array{T, N}(::UndefInitializer, ::Integer...) where {T, N} at baseext.jl:14
#   Array{T, N}(::Nothing, ::Any...) where {T, N} at baseext.jl:31
#   ...
#
# Stacktrace:
#  [1] top-level scope
#    @ In[8]:2
#  [2] eval
#    @ ./boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1116

# %%
v = Vector{Int64}(undef,7)
# Out:
# 7-element Vector{Int64}:
#  4740189392
#  4690577728
#  4691980256
#  4691980336
#  4691980416
#  4691980496
#  4666534512

# %%
# tuple
t = (1,2,3,4,5)
# Out:
# (1, 2, 3, 4, 5)

# %%
typeof(t) # it is a tuple , here we can not change the value of the elements as we have done in case of array.
# Out:
# NTuple{5, Int64}

# %%
# t[1] = 100 # this will give us an error.

# %%
df = (a=1.0,b="Hello",c=7)  # named Tupel
# Out:
# (a = 1.0, b = "Hello", c = 7)

# %%
df[1]
# Out:
# 1.0

# %%
df[2]
# Out:
# "Hello"

# %%
df[3]
# Out:
# 7

# %%
df.a
# Out:
# 1.0

# %%
df.b
# Out:
# "Hello"

# %%
df.c
# Out:
# 7

# %%
keys(df)
# Out:
# (:a, :b, :c)

# %%
values(df)
# Out:
# (1.0, "Hello", 7)

# %%
# Dictionaries
d = Dict('a' => 7.3 ,'b' => "Hello", 'c' => a1)
# Out:
# Dict{Char, Any} with 3 entries:
#   'a' => 7.3
#   'c' => [1.0e-323 NaN 2.25355e-314; 0.0 0.0 1.0e-323]…
#   'b' => "Hello"

# %%
d['a']
# Out:
# 7.3

# %%
d['b']
# Out:
# "Hello"

# %%
d['c']
# Out:
# 2×3×4×5×6 Array{Float64, 5}:
# [:, :, 1, 1, 1] =
#  1.0e-323  NaN    2.25355e-314
#  0.0         0.0  1.0e-323
#
# [:, :, 2, 1, 1] =
#    0.0  0.0           1.0e-323
#  NaN    2.25355e-314  0.0
#
# [:, :, 3, 1, 1] =
#  NaN    2.25355e-314    0.0
#    0.0  1.0e-323      NaN
#
# [:, :, 4, 1, 1] =
#  0.0           6.9301e-310  5.21502e-310
#  2.25355e-314  0.0          6.93014e-310
#
# [:, :, 1, 2, 1] =
#  2.25355e-314    0.0  0.0
#  1.0e-323      NaN    2.25355e-314
#
# [:, :, 2, 2, 1] =
#  1.0e-323  NaN    2.25355e-314
#  0.0         0.0  1.0e-323
#
# [:, :, 3, 2, 1] =
#    0.0  0.0           1.0e-323
#  NaN    2.25355e-314  0.0
#
# [:, :, 4, 2, 1] =
#  NaN    2.25355e-314    0.0
#    0.0  1.0e-323      NaN
#
# [:, :, 1, 3, 1] =
#  0.0           1.0e-323  NaN
#  2.25355e-314  0.0         0.0
#
# [:, :, 2, 3, 1] =
#  2.25355e-314    0.0  0.0
#  1.0e-323      NaN    2.25355e-314
#
# [:, :, 3, 3, 1] =
#  1.0e-323  NaN    2.25355e-314
#  0.0         0.0  1.0e-323
#
# [:, :, 4, 3, 1] =
# ...

# %%
# we can also pre=defined the type of elements we want to have in the Dictionaries
d1 = Dict{Any,Any}
d2 = Dict{String,Float64}
# Out:
# Dict{String, Float64}
